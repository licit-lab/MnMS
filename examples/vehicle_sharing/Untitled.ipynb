# %%
from mnms.io.graph import load_graph

mg=load_graph('mlgraph.json')

#odlayer = generate_grid_origin_destination_layer(0, 0, 300, 300, 3, 3)

# %%
import matplotlib.pyplot as plt
from mnms.tools.render import draw_roads, draw_line,draw_odlayer

fig, ax = plt.subplots(figsize=(16, 9))
draw_roads(ax,mg.roads,label_size=10)
#draw_odlayer(ax, mg)
